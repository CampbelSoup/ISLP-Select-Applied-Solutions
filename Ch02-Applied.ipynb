# %% [markdown]
# ### Chapter 2 Select Applied Solutions

# %%
import pandas as pd
from matplotlib.pyplot import subplots
from ISLP import load_data

# %% [markdown]
# **Problem 8**

# %%
college = pd.read_csv("Data/College.csv")
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college2 = college.iloc[:, 0]
college3 = college.rename({'Unnamed: 0': 'College'}, axis=1)
college3 = college3.set_index('College')
college = college3

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
pd.plotting.scatter_matrix(college[["Top10perc", "Apps", "Enroll"]])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %%
fig, ax = subplots(figsize = (8,8))
college.boxplot("Outstate", by = "Private", ax = ax)
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %%
college['Elite'] = pd.cut(college['Top10perc'], bins = [0,0.5,1], labels = ['No', 'Yes'])
pd.value_counts(college["Elite"])
# Out:
# C:\Users\campz\AppData\Local\Temp\ipykernel_39248\3722195196.py:3: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(college["Elite"])
# Elite
# Yes    3
# No     0
# Name: count, dtype: int64

# %%
fig, ax = subplots(2, 2, figsize = (8,8))
college["Grad.Rate"].plot.hist(ax=ax[0,0])
college['Accept'].plot.hist(ax = ax[0,1])
college["Personal"].plot.hist(ax=ax[1,0])
college["Top10perc"].plot.hist(ax=ax[1,1])
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **Problem 10**

# %%
Boston = load_data("Boston")
Boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %%
#Rows and Columns
Boston.shape
# Out:
# (506, 13)

# %%
pd.plotting.scatter_matrix(Boston, figsize= (12,12))
# Out:
# array([[<Axes: xlabel='crim', ylabel='crim'>,
#         <Axes: xlabel='zn', ylabel='crim'>,
#         <Axes: xlabel='indus', ylabel='crim'>,
#         <Axes: xlabel='chas', ylabel='crim'>,
#         <Axes: xlabel='nox', ylabel='crim'>,
#         <Axes: xlabel='rm', ylabel='crim'>,
#         <Axes: xlabel='age', ylabel='crim'>,
#         <Axes: xlabel='dis', ylabel='crim'>,
#         <Axes: xlabel='rad', ylabel='crim'>,
#         <Axes: xlabel='tax', ylabel='crim'>,
#         <Axes: xlabel='ptratio', ylabel='crim'>,
#         <Axes: xlabel='lstat', ylabel='crim'>,
#         <Axes: xlabel='medv', ylabel='crim'>],
#        [<Axes: xlabel='crim', ylabel='zn'>,
#         <Axes: xlabel='zn', ylabel='zn'>,
#         <Axes: xlabel='indus', ylabel='zn'>,
#         <Axes: xlabel='chas', ylabel='zn'>,
#         <Axes: xlabel='nox', ylabel='zn'>,
#         <Axes: xlabel='rm', ylabel='zn'>,
#         <Axes: xlabel='age', ylabel='zn'>,
#         <Axes: xlabel='dis', ylabel='zn'>,
# ...

# %% [markdown]
# Medv + rn are norm dist looking
# Linear relationship between rm and medv (+)

# %%
pd.plotting.scatter_matrix(Boston[["crim", "age", "dis", "medv", "rad", "tax"]], figsize= (12,12))
# Out:
# array([[<Axes: xlabel='crim', ylabel='crim'>,
#         <Axes: xlabel='age', ylabel='crim'>,
#         <Axes: xlabel='dis', ylabel='crim'>,
#         <Axes: xlabel='medv', ylabel='crim'>,
#         <Axes: xlabel='rad', ylabel='crim'>,
#         <Axes: xlabel='tax', ylabel='crim'>],
#        [<Axes: xlabel='crim', ylabel='age'>,
#         <Axes: xlabel='age', ylabel='age'>,
#         <Axes: xlabel='dis', ylabel='age'>,
#         <Axes: xlabel='medv', ylabel='age'>,
#         <Axes: xlabel='rad', ylabel='age'>,
#         <Axes: xlabel='tax', ylabel='age'>],
#        [<Axes: xlabel='crim', ylabel='dis'>,
#         <Axes: xlabel='age', ylabel='dis'>,
#         <Axes: xlabel='dis', ylabel='dis'>,
#         <Axes: xlabel='medv', ylabel='dis'>,
#         <Axes: xlabel='rad', ylabel='dis'>,
#         <Axes: xlabel='tax', ylabel='dis'>],
#        [<Axes: xlabel='crim', ylabel='medv'>,
#         <Axes: xlabel='age', ylabel='medv'>,
#         <Axes: xlabel='dis', ylabel='medv'>,
# ...

# %%
Boston.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# Rad, tax have a relatively strong positive correlation

# %%
Boston[["tax", "crim", "ptratio"]].describe()
# Out:
#               tax        crim     ptratio
# count  506.000000  506.000000  506.000000
# mean   408.237154    3.613524   18.455534
# std    168.537116    8.601545    2.164946
# min    187.000000    0.006320   12.600000
# 25%    279.000000    0.082045   17.400000
# 50%    330.000000    0.256510   19.050000
# 75%    666.000000    3.677083   20.200000
# max    711.000000   88.976200   22.000000

# %%
#Smallest 10 tax regions
Boston.iloc[Boston['tax'].nsmallest(10).index]
# Out:
#         crim    zn  indus  chas    nox     rm   age      dis  rad  tax  \
# 353  0.01709  90.0   2.02     0  0.410  6.728  36.1  12.1265    5  187
# 120  0.06899   0.0  25.65     0  0.581  5.870  69.7   2.2577    2  188
# 121  0.07165   0.0  25.65     0  0.581  6.004  84.1   2.1974    2  188
# 122  0.09299   0.0  25.65     0  0.581  5.961  92.9   2.0869    2  188
# 123  0.15038   0.0  25.65     0  0.581  5.856  97.0   1.9444    2  188
# 124  0.09849   0.0  25.65     0  0.581  5.879  95.8   2.0063    2  188
# 125  0.16902   0.0  25.65     0  0.581  5.986  88.4   1.9929    2  188
# 126  0.38735   0.0  25.65     0  0.581  5.613  95.6   1.7572    2  188
# 179  0.05780   0.0   2.46     0  0.488  6.980  58.4   2.8290    3  193
# 180  0.06588   0.0   2.46     0  0.488  7.765  83.3   2.7410    3  193
#
#      ptratio  lstat  medv
# 353     17.0   4.50  30.1
# 120     19.1  14.37  22.0
# 121     19.1  14.27  20.3
# 122     19.1  17.93  20.5
# 123     19.1  25.41  17.3
# ...

# %%
Boston['chas'].value_counts()[1]
# Out:
# 35

# %%
Boston['ptratio'].median()
# Out:
# 19.05

# %%
Boston["medv"].argmin()
# Out:
# 398

# %%
Boston.loc[Boston["medv"].idxmin()]
# Out:
# crim        38.3518
# zn           0.0000
# indus       18.1000
# chas         0.0000
# nox          0.6930
# rm           5.4530
# age        100.0000
# dis          1.4896
# rad         24.0000
# tax        666.0000
# ptratio     20.2000
# lstat       30.5900
# medv         5.0000
# Name: 398, dtype: float64

# %%
len(Boston[Boston['rm'] > 7])
# Out:
# 64

# %%
len(Boston[Boston['rm'] > 8])
# Out:
# 13

# %%
Boston[Boston['rm'] > 8].describe()
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio      lstat  \
# count  13.000000  13.000000  13.000000   13.000000  13.000000  13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538   4.310000
# std    24.608723   1.883955   5.332532  110.971063   2.410580   1.373566
# ...
